# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

# %%
api_key = 'AIzaSyCdfhpEzNsOkLcTUiGfqUUAlx8dtvdHCUo'

# %%
channel_ids = [
    'UCLwAh2ZhRXOLnivs9DXW1xg',
]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):

    all_data = []
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#       channelName subscribers views totalVideos                playlistId
# 0  BOIKUSS GAMMER         135  6767          64  UULwAh2ZhRXOLnivs9DXW1xg

# %%
playlist_id = "UULwAh2ZhRXOLnivs9DXW1xg"

def get_video_ids(youtube, playlist_id):
    video_ids = []

    # Initial request
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()

    # Loop to fetch all pages
    while True:
        for item in response.get('items', []):
            video_ids.append(item['contentDetails']['videoId'])
        
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break  # No more pages
        
        # Use next_page_token in the next request
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response = request.execute()

    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids), video_ids
# Out:
# (64,
#  ['YMksIj9yVok',
#   'ivpbfxarmUA',
#   'AqkJ_u59VPI',
#   '8lLv1ygnErc',
#   'iVhJJxN4yLU',
#   '30AZCq7g1vk',
#   'kq9LOYay1LA',
#   'HzmdOJNgLGE',
#   'GrLsARTVRLc',
#   'xOY5sEmnbA4',
#   'D3eeVKdlTj8',
#   'xJOWG2uslwA',
#   '0jXKPOyJ3Ss',
#   'eQ0j-q3b2tk',
#   '08IP7zSxUIk',
#   'XgomFqCDK2o',
#   'dPN6aK7fg_A',
#   '3gWxAM_0IaM',
#   'lPfjfbbJ-zk',
#   'fs8iiaG190A',
#   'hBJNrMn6iMA',
#   'TZ_R2fz7C8s',
#   '2ak96tsiOq8',
#   'jdnJtQ1oO2s',
#   'QkzMEn7ANas',
#   'RVosE7kU9IE',
#   '96MUkBvN_2A',
#   'oLcmbcs-GlE',
#   'KXbczttZhaE',
#   'Mnzgwuxd3Gg',
#   'Gqux1q5pWJE',
#   '7VGxSOIdMQs',
#   '4-BspECSRuc',
#   '-LDkzFtoem4',
#   'erE7HJQrjgE',
#   'QFIF7HojsGE',
#   'ugQ78TEUR8c',
#   '7W1EUh-FPdk',
#   'zik94GNMHsE',
#   'fQdk7kOGGfY',
#   'RkBvqefxkbU',
#   'p8pmyJrQ2Gw',
#   'ph44uyFEAGo',
#   'USY1pr6YniA',
#   'Kx8Lx03ngak',
#   'MHwtyaOwOhc',
#   '39nAIXUtwcQ',
#   'Sgfimv8udvg',
#   'pu37uhe1Jn8',
#   'BtM7wpbkO_Q',
#   'gaumFUplPWQ',
#   'iGRYPz9YOug',
# ...

# %%
def get_video_details(youtube, video_ids):
    
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet, contentDetails, statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favoriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                        }

            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)

    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#        video_id    channelTitle  \
# 0   YMksIj9yVok  BOIKUSS GAMMER
# 1   ivpbfxarmUA  BOIKUSS GAMMER
# 2   AqkJ_u59VPI  BOIKUSS GAMMER
# 3   8lLv1ygnErc  BOIKUSS GAMMER
# 4   iVhJJxN4yLU  BOIKUSS GAMMER
# ..          ...             ...
# 59  -fFKM70ci5U  BOIKUSS GAMMER
# 60  qm-F8uP_LGw  BOIKUSS GAMMER
# 61  ug78j_rXsz4  BOIKUSS GAMMER
# 62  zlvJCKz-w5Q  BOIKUSS GAMMER
# 63  iJsRFzxTfTw  BOIKUSS GAMMER
#
#                                                 title  \
# 0   💀 "CS-Ranked INSANE 14 KILLS at ELITE MASTER! ...
# 1   💥 "ONLY 3 SPINS?! Unbelievable Luck in Moco St...
# 2   Solo  RANKED | 13 Kills | Epic MAG-7 vs Double...
# 3   🔥 15 Kills BR Rank Domination with M590! Epic ...
# 4   🔥 Mastering M590 And M249 in FFMAX! Insane 12 ...
# ..                                                ...
# 59  Free Fire BR Ranked: 13 Kills Showdown! Surviv...
# 60  Clutch 1v1 Lone Wolf DOMINATES in Free Fire (M...
# 61  Lone Wolf Domination: 1v1 Showdowns! (Free Fir...
# ...

# %%
def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    
    for video_id in video_ids:
        # Use commentThreads() and videoId parameter for fetching comments
        request = youtube.commentThreads().list(
            part="snippet,replies",
            videoId=video_id,
            maxResults=100  # Adjust this as needed
        )
        response = request.execute()
        
        # Iterate over the 'items' key in the response
        comments_on_video = [
            comment['snippet']['topLevelComment']['snippet']['textOriginal']
            for comment in response.get('items', [])
        ]
        
        comments_on_video_info = {'video_id': video_id, 'comments': comments_on_video}
        all_comments.append(comments_on_video_info)
    
    return pd.DataFrame(all_comments)

# %%
all_comments = get_comments_in_videos(youtube, video_ids)
all_comments
# Out:
#        video_id                                           comments
# 0   YMksIj9yVok  [New subscribers🎉😮, ❤🔥💯, Nice gameplay bro ❣️🌹...
# 1   ivpbfxarmUA  [ᴍɪᴛᴇ❤, Damn ya lucky bro wow....🎉🎉🎉🎉🎉❤, Full ...
# 2   AqkJ_u59VPI  [A Squad a hng u leh bon alo naji helou uva so...
# 3   8lLv1ygnErc           [Number 2 chu koi hia ana sa kei e ☺️😆🤣]
# 4   iVhJJxN4yLU             [😮 .....sirji dj alok dedo😂, Pin it 😂]
# ..          ...                                                ...
# 59  -fFKM70ci5U  [Free fire stocks rn📈📈, ʟᴏᴠᴇ ғʀᴏᴍ ᴊᴀᴘᴀɴ, ❤❤❤ni...
# 60  qm-F8uP_LGw       [ʟᴏᴠᴇ ғʀᴏᴍ ᴊᴀᴘᴀɴ, 🤩 ❤wow, Damn🙇, Wow... Op²]
# 61  ug78j_rXsz4  [ʟᴏᴠᴇ ғʀᴏᴍ ᴊᴀᴘᴀɴ, BL FUH E😌, You really are th...
# 62  zlvJCKz-w5Q  [Another one❤❤, ʀᴇᴀʟʟʏ ʟᴏᴠᴇ ʏᴏᴜʀ ᴠɪᴅᴇᴏ, ʟᴏᴠᴇ ғ...
# 63  iJsRFzxTfTw  [Wow ….kanao pa chu them ta❤❤❤, Full Support K...
#
# [64 rows x 2 columns]
